# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Shouban7866/flyrank-ml-internship/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %% [markdown]
# The feature vector is built by selecting relevant SEO and content performance features from the dataset. Missing values are handled before training, and categorical features are encoded when required. These features are used as input for the machine learning model.

# %%
import pandas as pd

df = pd.read_csv("/content/content_refresh_anonymized.csv")

features = [
    "search_volume",
    "competition",
    "cpc",
    "word_count",
    "impressions_90d",
    "clicks_90d",
    "sessions_90d",
    "ctr",
    "avg_position",
    "engagement_rate",
    "scroll_rate",
    "content_age_days"
]

X = df[features].fillna(0)

print(X.head())
print("Feature Shape:", X.shape)
# Out:
#    search_volume  competition   cpc  word_count  impressions_90d  clicks_90d  \
# 0           10.0         0.67  2.05      3221.0             3803          29
# 1           90.0         0.01  0.05      2481.0            15320           7
# 2            0.0         0.00  0.00      3515.0            12581          11
# 3           10.0         0.00  0.00         0.0            11751          58
# 4            0.0         0.00  0.00      2803.0            19140          24
#
#    sessions_90d   ctr  avg_position  engagement_rate  scroll_rate  \
# 0            17  0.76          10.6             5.88         4.55
# 1             9  0.05          20.3             0.00        10.00
# 2            11  0.09          36.5             0.00        28.57
# 3            78  0.49           6.2             1.28         3.45
# 4           145  0.13          44.0             0.00        24.29
#
#    content_age_days
# 0               187
# 1               445
# 2               141
# ...

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %% [markdown]
# The selected features describe SEO performance, content quality, and user engagement. Missing numerical values are filled with 0 for this baseline analysis. All selected features are available before prediction and do not directly reveal the target label.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %% [markdown]
# The feature vector does not include any target label or identifier. Future information and label-derived values are excluded to reduce the risk of data leakage. Only features available at prediction time are used.

# %%
print("Features Used:")
print(features)

print("\nExcluded Fields:")
print(["content_id", "client_id"])
# Out:
# Features Used:
# ['search_volume', 'competition', 'cpc', 'word_count', 'impressions_90d', 'clicks_90d', 'sessions_90d', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'content_age_days']
#
# Excluded Fields:
# ['content_id', 'client_id']

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %% [markdown]
# content_id and client_id were excluded because they are identifiers and do not provide useful predictive information. The target label is also excluded from the feature vector to avoid data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
